# %% [markdown]
# <a href="https://colab.research.google.com/github/Elish-Ab/AI-Mastery-10x/blob/main/EDA_task1_Region3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('togo-dapaong_qc.csv')

# %%
df.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-25 00:01 -1.3  0.0  0.0   0.0   0.0  24.8  94.5  0.9     1.1
# 1  2021-10-25 00:02 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.1     1.6
# 2  2021-10-25 00:03 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.2     1.4
# 3  2021-10-25 00:04 -1.2  0.0  0.0   0.0   0.0  24.8  94.3  1.2     1.6
# 4  2021-10-25 00:05 -1.2  0.0  0.0   0.0   0.0  24.8  94.0  1.3     1.6
#
#    WSstdev     WD  WDstdev     BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.4  227.6      1.1  977.0       0.0            0.0   24.7   24.4
# 1      0.4  229.3      0.7  977.0       0.0            0.0   24.7   24.4
# 2      0.3  228.5      2.9  977.0       0.0            0.0   24.7   24.4
# 3      0.3  229.1      4.6  977.0       0.0            0.0   24.7   24.4
# 4      0.4  227.5      1.6  977.0       0.0            0.0   24.7   24.4
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44129 entries, 0 to 44128
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      44129 non-null  object
#  1   GHI            44129 non-null  float64
#  2   DNI            44129 non-null  float64
#  3   DHI            44128 non-null  float64
#  4   ModA           44128 non-null  float64
#  5   ModB           44128 non-null  float64
#  6   Tamb           44128 non-null  float64
#  7   RH             44128 non-null  float64
#  8   WS             44128 non-null  float64
#  9   WSgust         44128 non-null  float64
#  10  WSstdev        44128 non-null  float64
#  11  WD             44128 non-null  float64
#  12  WDstdev        44128 non-null  float64
#  13  BP             44128 non-null  float64
#  14  Cleaning       44128 non-null  float64
#  15  Precipitation  44128 non-null  float64
#  16  TModA          44128 non-null  float64
#  17  TModB          44128 non-null  float64
#  18  Comments       0 non-null      float64
# dtypes: float64(18), object(1)
# memory usage: 6.4+ MB

# %%
df.describe()
# Out:
#                 GHI           DNI           DHI          ModA          ModB  \
# count  44129.000000  44129.000000  44128.000000  44128.000000  44128.000000
# mean     247.706921    238.957683     85.225981    265.695769    255.728900
# std      333.931405    316.813119    110.835876    354.868418    341.921743
# min       -6.300000      0.000000      0.000000      0.000000      0.000000
# 25%       -2.500000      0.000000      0.000000      0.000000      0.000000
# 50%       -0.900000      0.000000      0.600000      1.200000      1.200000
# 75%      530.300000    561.700000    161.600000    566.350000    543.325000
# max     1139.000000    989.800000    585.300000   1172.000000   1154.000000
#
#                Tamb            RH            WS        WSgust       WSstdev  \
# count  44128.000000  44128.000000  44128.000000  44128.000000  44128.000000
# mean      28.765410     56.482070      1.976919      2.637878      0.468344
# std        4.230137     20.579189      1.096289      1.388698      0.206428
# min       20.100000     12.500000      0.000000      0.000000      0.000000
# 25%       25.200000     39.600000      1.300000      1.900000      0.400000
# 50%       27.900000     57.900000      2.000000      2.600000      0.400000
# 75%       32.400000     73.600000      2.600000      3.400000      0.600000
# max       38.000000     95.900000     14.300000     19.300000      3.200000
#
#                  WD       WDstdev            BP      Cleaning  Precipitation  \
# count  44128.000000  44128.000000  44128.000000  44128.000000   44128.000000
# mean     180.147761      9.124767    975.416765      0.000544       0.000197
# std       89.371923      6.455108      1.584866      0.023315       0.008891
# min        0.000000      0.000000    972.000000      0.000000       0.000000
# 25%      103.500000      4.500000    974.000000      0.000000       0.000000
# 50%      213.300000      8.600000    975.000000      0.000000       0.000000
# 75%      242.700000     12.800000    977.000000      0.000000       0.000000
# max      360.000000     79.600000    980.000000      1.000000       0.700000
#
#               TModA         TModB  Comments
# count  44128.000000  44128.000000       0.0
# mean      34.255581     35.305566       NaN
# std       12.471358     14.207622       NaN
# min       17.300000     17.100000       NaN
# 25%       24.200000     23.900000       NaN
# 50%       27.500000     27.200000       NaN
# 75%       45.100000     48.000000       NaN
# max       65.000000     69.500000       NaN

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Timestamp            0
# GHI                  0
# DNI                  0
# DHI                  1
# ModA                 1
# ModB                 1
# Tamb                 1
# RH                   1
# WS                   1
# WSgust               1
# WSstdev              1
# WD                   1
# WDstdev              1
# BP                   1
# Cleaning             1
# Precipitation        1
# TModA                1
# TModB                1
# Comments         44129
# dtype: int64

# %%
# Visualize outliers using box plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']])
plt.title('Box Plot for Outlier Detection')
plt.show()

# %%
incorrect_entries = df[(df['GHI'] < 0) | (df['DNI'] < 0) | (df['DHI'] < 0)]
print("Incorrect entries:\n", incorrect_entries)
# Out:
# Incorrect entries:
#                Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0      2021-10-25 00:01 -1.3  0.0  0.0   0.0   0.0  24.8  94.5  0.9     1.1
# 1      2021-10-25 00:02 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.1     1.6
# 2      2021-10-25 00:03 -1.3  0.0  0.0   0.0   0.0  24.8  94.4  1.2     1.4
# 3      2021-10-25 00:04 -1.2  0.0  0.0   0.0   0.0  24.8  94.3  1.2     1.6
# 4      2021-10-25 00:05 -1.2  0.0  0.0   0.0   0.0  24.8  94.0  1.3     1.6
# ...                 ...  ...  ...  ...   ...   ...   ...   ...  ...     ...
# 43551  2021-11-24 05:52 -1.3  0.0  0.7   1.4   1.3  21.0  48.2  0.9     1.4
# 43552  2021-11-24 05:53 -1.1  0.0  0.8   1.7   1.6  20.9  49.1  0.7     1.1
# 43553  2021-11-24 05:54 -0.9  0.0  0.9   1.9   1.8  20.9  49.0  1.1     1.6
# 43554  2021-11-24 05:55 -0.6  0.0  1.1   2.3   2.2  20.9  48.2  0.8     1.1
# 43555  2021-11-24 05:56 -0.2  0.0  1.2   2.6   2.5  20.8  48.0  0.9     1.4
#
#        WSstdev     WD  WDstdev     BP  Cleaning  Precipitation  TModA  TModB  \
# 0          0.4  227.6      1.1  977.0       0.0            0.0   24.7   24.4
# 1          0.4  229.3      0.7  977.0       0.0            0.0   24.7   24.4
# 2          0.3  228.5      2.9  977.0       0.0            0.0   24.7   24.4
# 3          0.3  229.1      4.6  977.0       0.0            0.0   24.7   24.4
# 4          0.4  227.5      1.6  977.0       0.0            0.0   24.7   24.4
# ...        ...    ...      ...    ...       ...            ...    ...    ...
# 43551      0.4  125.9      3.5  977.0       0.0            0.0   18.0   17.7
# 43552      0.5  126.3      1.5  977.0       0.0            0.0   17.9   17.7
# 43553      0.5  122.4      3.5  977.0       0.0            0.0   17.9   17.7
# 43554      0.5  120.5      3.1  977.0       0.0            0.0   17.8   17.6
# 43555      0.5  121.8      1.7  977.0       0.0            0.0   17.8   17.6
#
#        Comments
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 43551       NaN
# 43552       NaN
# 43553       NaN
# 43554       NaN
# 43555       NaN
#
# [22418 rows x 19 columns]

# %%
df.describe(include=[np.number])
# Out:
#                 GHI           DNI           DHI          ModA          ModB  \
# count  44129.000000  44129.000000  44128.000000  44128.000000  44128.000000
# mean     247.706921    238.957683     85.225981    265.695769    255.728900
# std      333.931405    316.813119    110.835876    354.868418    341.921743
# min       -6.300000      0.000000      0.000000      0.000000      0.000000
# 25%       -2.500000      0.000000      0.000000      0.000000      0.000000
# 50%       -0.900000      0.000000      0.600000      1.200000      1.200000
# 75%      530.300000    561.700000    161.600000    566.350000    543.325000
# max     1139.000000    989.800000    585.300000   1172.000000   1154.000000
#
#                Tamb            RH            WS        WSgust       WSstdev  \
# count  44128.000000  44128.000000  44128.000000  44128.000000  44128.000000
# mean      28.765410     56.482070      1.976919      2.637878      0.468344
# std        4.230137     20.579189      1.096289      1.388698      0.206428
# min       20.100000     12.500000      0.000000      0.000000      0.000000
# 25%       25.200000     39.600000      1.300000      1.900000      0.400000
# 50%       27.900000     57.900000      2.000000      2.600000      0.400000
# 75%       32.400000     73.600000      2.600000      3.400000      0.600000
# max       38.000000     95.900000     14.300000     19.300000      3.200000
#
#                  WD       WDstdev            BP      Cleaning  Precipitation  \
# count  44128.000000  44128.000000  44128.000000  44128.000000   44128.000000
# mean     180.147761      9.124767    975.416765      0.000544       0.000197
# std       89.371923      6.455108      1.584866      0.023315       0.008891
# min        0.000000      0.000000    972.000000      0.000000       0.000000
# 25%      103.500000      4.500000    974.000000      0.000000       0.000000
# 50%      213.300000      8.600000    975.000000      0.000000       0.000000
# 75%      242.700000     12.800000    977.000000      0.000000       0.000000
# max      360.000000     79.600000    980.000000      1.000000       0.700000
#
#               TModA         TModB  Comments
# count  44128.000000  44128.000000       0.0
# mean      34.255581     35.305566       NaN
# std       12.471358     14.207622       NaN
# min       17.300000     17.100000       NaN
# 25%       24.200000     23.900000       NaN
# 50%       27.500000     27.200000       NaN
# 75%       45.100000     48.000000       NaN
# max       65.000000     69.500000       NaN

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)

plt.figure(figsize=(14, 7))
df[['GHI', 'DNI', 'DHI', 'Tamb']].resample('M').mean().plot()
plt.title('Monthly Trends of Solar Irradiance and Temperature')
plt.show()

# %%
sns.lineplot(data=df, x='Timestamp', y='ModA', hue='Cleaning')
plt.title('Impact of Cleaning Events on ModA Sensor Readings')
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)
ax.scatter(np.deg2rad(df['WD']), df['WS'])
ax.set_title('Polar Plot of Wind Direction and Speed')
plt.show()

# %%
sns.scatterplot(data=df, x='RH', y='Tamb', hue='GHI')
plt.title('Relationship Between Humidity, Temperature, and GHI')
plt.show()

# %%
df[['GHI', 'DNI', 'DHI', 'WS', 'Tamb']].hist(bins=30, figsize=(15, 10))
plt.suptitle('Histograms of Key Variables')
plt.show()

# %%
df['GHI_zscore'] = stats.zscore(df['GHI'])
outliers = df[df['GHI_zscore'].abs() > 3]  # Flag values with z-score > 3
print("Outliers based on Z-score:\n", outliers)
# Out:
# Outliers based on Z-score:
#  Empty DataFrame
# Columns: [GHI, DNI, DHI, ModA, ModB, Tamb, RH, WS, WSgust, WSstdev, WD, WDstdev, BP, Cleaning, Precipitation, TModA, TModB, Comments, GHI_zscore]
# Index: []

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='GHI', y='Tamb', size='RH', hue='WS', sizes=(20, 200), alpha=0.5)
plt.title('Bubble Chart of GHI vs. Temperature vs. Wind Speed')
plt.show()

# %%
df.fillna(df.mean(), inplace=True)

# %%
# Removing rows with extreme Z-scores
df = df[df['GHI_zscore'].abs() <= 3]

# %%
df.drop(columns=['Comments'], inplace=True)
