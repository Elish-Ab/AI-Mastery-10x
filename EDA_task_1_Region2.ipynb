# %% [markdown]
# <a href="https://colab.research.google.com/github/Elish-Ab/AI-Mastery-10x/blob/task-1/EDA_task_1_Region2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('sierraleone-bumbuna.csv')

# %%
df.head()
# Out:
#           Timestamp  GHI  DNI  DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0  2021-10-30 00:01 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1  2021-10-30 00:02 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2  2021-10-30 00:03 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3  2021-10-30 00:04 -0.7  0.0 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4  2021-10-30 00:05 -0.7 -0.1 -0.8   0.0   0.0  21.9  99.3  0.0     0.0
#
#    WSstdev   WD  WDstdev      BP  Cleaning  Precipitation  TModA  TModB  \
# 0      0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 1      0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 2      0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 3      0.0  0.0      0.0  1002.0       0.0            0.1   22.3   22.6
# 4      0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
#
#    Comments
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60120 entries, 0 to 60119
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      60120 non-null  object
#  1   GHI            60120 non-null  float64
#  2   DNI            60120 non-null  float64
#  3   DHI            60120 non-null  float64
#  4   ModA           60120 non-null  float64
#  5   ModB           60120 non-null  float64
#  6   Tamb           60120 non-null  float64
#  7   RH             60120 non-null  float64
#  8   WS             60120 non-null  float64
#  9   WSgust         60120 non-null  float64
#  10  WSstdev        60120 non-null  float64
#  11  WD             60120 non-null  float64
#  12  WDstdev        60120 non-null  float64
#  13  BP             60119 non-null  float64
#  14  Cleaning       60119 non-null  float64
#  15  Precipitation  60119 non-null  float64
#  16  TModA          60119 non-null  float64
#  17  TModB          60119 non-null  float64
#  18  Comments       0 non-null      float64
# dtypes: float64(18), object(1)
# memory usage: 8.7+ MB

# %%
df.describe()
# Out:
#                 GHI           DNI           DHI          ModA          ModB  \
# count  60120.000000  60120.000000  60120.000000  60120.000000  60120.000000
# mean     216.527482    167.277299     98.448007    235.090833    227.395479
# std      311.085756    274.249561    133.170596    338.111250    327.690482
# min       -5.000000     -3.900000     -4.200000      0.000000      0.000000
# 25%       -1.300000     -0.200000     -1.400000      0.000000      0.000000
# 50%       -0.100000      0.000000     -0.100000      1.000000      0.900000
# 75%      393.525000    288.525000    192.100000    424.800000    409.825000
# max     1232.000000    896.000000    666.000000   1316.000000   1285.000000
#
#                Tamb            RH            WS        WSgust       WSstdev  \
# count  60120.000000  60120.000000  60120.000000  60120.000000  60120.000000
# mean      26.486213     85.746954      1.005719      1.477410      0.343408
# std        3.714169     14.148579      1.025156      1.326292      0.256046
# min       19.000000     35.500000      0.000000      0.000000      0.000000
# 25%       23.300000     73.300000      0.000000      0.000000      0.000000
# 50%       25.300000     92.300000      0.800000      1.400000      0.400000
# 75%       30.100000     97.900000      1.700000      2.400000      0.500000
# max       36.300000    100.000000     10.100000     13.800000      3.500000
#
#                  WD       WDstdev            BP      Cleaning  Precipitation  \
# count  60120.000000  60120.000000  60119.000000  60119.000000   60119.000000
# mean     137.752021      6.661051    999.465793      0.000915       0.001692
# std      119.351607      7.550295      1.763606      0.030233       0.024552
# min        0.000000      0.000000    995.000000      0.000000       0.000000
# 25%        0.000000      0.000000    998.000000      0.000000       0.000000
# 50%      148.400000      4.700000   1000.000000      0.000000       0.000000
# 75%      248.700000     11.400000   1001.000000      0.000000       0.000000
# max      360.000000     93.300000   1006.000000      1.000000       1.500000
#
#               TModA         TModB  Comments
# count  60119.000000  60119.000000       0.0
# mean      34.389764     34.275301       NaN
# std       14.070042     13.232179       NaN
# min       18.000000     18.400000       NaN
# 25%       23.500000     23.900000       NaN
# 50%       26.000000     26.400000       NaN
# 75%       45.800000     45.800000       NaN
# max       72.800000     66.900000       NaN

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Timestamp            0
# GHI                  0
# DNI                  0
# DHI                  0
# ModA                 0
# ModB                 0
# Tamb                 0
# RH                   0
# WS                   0
# WSgust               0
# WSstdev              0
# WD                   0
# WDstdev              0
# BP                   1
# Cleaning             1
# Precipitation        1
# TModA                1
# TModB                1
# Comments         60120
# dtype: int64

# %%
# Visualize outliers using box plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['GHI', 'DNI', 'DHI', 'ModA', 'ModB', 'WS', 'WSgust']])
plt.title('Box Plot for Outlier Detection')
plt.show()

# %%
incorrect_entries = df[(df['GHI'] < 0) | (df['DNI'] < 0) | (df['DHI'] < 0)]
print("Incorrect entries:\n", incorrect_entries)
# Out:
# Incorrect entries:
#                Timestamp   GHI  DNI   DHI  ModA  ModB  Tamb    RH   WS  WSgust  \
# 0      2021-10-30 00:01  -0.7 -0.1  -0.8   0.0   0.0  21.9  99.1  0.0     0.0
# 1      2021-10-30 00:02  -0.7 -0.1  -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 2      2021-10-30 00:03  -0.7 -0.1  -0.8   0.0   0.0  21.9  99.2  0.0     0.0
# 3      2021-10-30 00:04  -0.7  0.0  -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# 4      2021-10-30 00:05  -0.7 -0.1  -0.8   0.0   0.0  21.9  99.3  0.0     0.0
# ...                 ...   ...  ...   ...   ...   ...   ...   ...  ...     ...
# 59478  2021-12-10 07:19  27.3 -0.1  27.2  31.4  29.2  22.7  99.7  0.0     0.0
# 59479  2021-12-10 07:20  28.7 -0.1  28.6  33.0  30.7  22.7  99.7  0.0     0.0
# 59480  2021-12-10 07:21  30.2 -0.1  30.1  34.6  32.2  22.7  99.7  0.0     0.0
# 59481  2021-12-10 07:22  31.7 -0.1  31.5  36.3  33.8  22.7  99.5  0.0     0.7
# 59482  2021-12-10 07:23  33.2 -0.1  33.0  37.9  35.3  22.7  99.5  0.0     0.0
#
#        WSstdev   WD  WDstdev      BP  Cleaning  Precipitation  TModA  TModB  \
# 0          0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 1          0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 2          0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# 3          0.0  0.0      0.0  1002.0       0.0            0.1   22.3   22.6
# 4          0.0  0.0      0.0  1002.0       0.0            0.0   22.3   22.6
# ...        ...  ...      ...     ...       ...            ...    ...    ...
# 59478      0.0  0.0      0.0   998.0       0.0            0.0   23.0   23.3
# 59479      0.0  0.0      0.0   998.0       0.0            0.0   23.1   23.3
# 59480      0.0  0.0      0.0   998.0       0.0            0.0   23.1   23.4
# 59481      0.2  7.5      0.0   998.0       0.0            0.0   23.2   23.4
# 59482      0.0  0.0      0.0   998.0       0.0            0.0   23.2   23.5
#
#        Comments
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 59478       NaN
# 59479       NaN
# 59480       NaN
# 59481       NaN
# 59482       NaN
#
# [32993 rows x 19 columns]

# %%
df.describe(include=[np.number])
# Out:
#                 GHI           DNI           DHI          ModA          ModB  \
# count  60120.000000  60120.000000  60120.000000  60120.000000  60120.000000
# mean     216.527482    167.277299     98.448007    235.090833    227.395479
# std      311.085756    274.249561    133.170596    338.111250    327.690482
# min       -5.000000     -3.900000     -4.200000      0.000000      0.000000
# 25%       -1.300000     -0.200000     -1.400000      0.000000      0.000000
# 50%       -0.100000      0.000000     -0.100000      1.000000      0.900000
# 75%      393.525000    288.525000    192.100000    424.800000    409.825000
# max     1232.000000    896.000000    666.000000   1316.000000   1285.000000
#
#                Tamb            RH            WS        WSgust       WSstdev  \
# count  60120.000000  60120.000000  60120.000000  60120.000000  60120.000000
# mean      26.486213     85.746954      1.005719      1.477410      0.343408
# std        3.714169     14.148579      1.025156      1.326292      0.256046
# min       19.000000     35.500000      0.000000      0.000000      0.000000
# 25%       23.300000     73.300000      0.000000      0.000000      0.000000
# 50%       25.300000     92.300000      0.800000      1.400000      0.400000
# 75%       30.100000     97.900000      1.700000      2.400000      0.500000
# max       36.300000    100.000000     10.100000     13.800000      3.500000
#
#                  WD       WDstdev            BP      Cleaning  Precipitation  \
# count  60120.000000  60120.000000  60119.000000  60119.000000   60119.000000
# mean     137.752021      6.661051    999.465793      0.000915       0.001692
# std      119.351607      7.550295      1.763606      0.030233       0.024552
# min        0.000000      0.000000    995.000000      0.000000       0.000000
# 25%        0.000000      0.000000    998.000000      0.000000       0.000000
# 50%      148.400000      4.700000   1000.000000      0.000000       0.000000
# 75%      248.700000     11.400000   1001.000000      0.000000       0.000000
# max      360.000000     93.300000   1006.000000      1.000000       1.500000
#
#               TModA         TModB  Comments
# count  60119.000000  60119.000000       0.0
# mean      34.389764     34.275301       NaN
# std       14.070042     13.232179       NaN
# min       18.000000     18.400000       NaN
# 25%       23.500000     23.900000       NaN
# 50%       26.000000     26.400000       NaN
# 75%       45.800000     45.800000       NaN
# max       72.800000     66.900000       NaN

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)

plt.figure(figsize=(14, 7))
df[['GHI', 'DNI', 'DHI', 'Tamb']].resample('M').mean().plot()
plt.title('Monthly Trends of Solar Irradiance and Temperature')
plt.show()

# %%
sns.lineplot(data=df, x='Timestamp', y='ModA', hue='Cleaning')
plt.title('Impact of Cleaning Events on ModA Sensor Readings')
plt.show()

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)
ax.scatter(np.deg2rad(df['WD']), df['WS'])
ax.set_title('Polar Plot of Wind Direction and Speed')
plt.show()

# %%
sns.scatterplot(data=df, x='RH', y='Tamb', hue='GHI')
plt.title('Relationship Between Humidity, Temperature, and GHI')
plt.show()

# %%
df['GHI_zscore'] = stats.zscore(df['GHI'])
outliers = df[df['GHI_zscore'].abs() > 3]  # Flag values with z-score > 3
print("Outliers based on Z-score:\n", outliers)
# Out:
# Outliers based on Z-score:
#                          GHI    DNI    DHI    ModA    ModB  Tamb    RH   WS  \
# Timestamp
# 2021-10-30 11:12:00  1154.0  755.7  491.3  1237.0  1208.0  27.0  82.4  1.2
# 2021-10-30 13:03:00  1151.0  813.0  400.1  1226.0  1198.0  30.0  72.2  2.1
# 2021-10-30 13:11:00  1184.0  773.5  471.7  1259.0  1231.0  29.5  72.0  1.6
# 2021-11-06 12:13:00  1157.0  709.9  509.2  1212.0  1183.0  31.0  67.6  3.2
# 2021-11-06 12:14:00  1165.0  715.6  513.3  1218.0  1190.0  31.1  67.4  3.2
# 2021-11-06 12:15:00  1158.0  718.4  503.9  1209.0  1181.0  31.1  66.5  2.8
# 2021-11-11 12:18:00  1232.0  795.4  514.1  1316.0  1285.0  29.7  77.2  1.3
# 2021-11-11 12:19:00  1206.0  786.2  494.2  1282.0  1252.0  29.9  77.3  1.2
# 2021-11-11 12:20:00  1197.0  792.8  481.7  1285.0  1255.0  30.1  76.8  2.3
# 2021-11-27 12:27:00  1166.0  751.7  507.8  1261.0  1205.0  30.5  75.6  2.7
# 2021-11-27 12:28:00  1174.0  756.1  511.1  1267.0  1211.0  30.5  74.3  3.1
# 2021-11-27 12:29:00  1181.0  764.5  510.8  1273.0  1216.0  30.4  75.2  1.8
# 2021-11-27 12:30:00  1180.0  764.7  509.9  1270.0  1214.0  30.5  74.3  2.2
# 2021-11-27 12:31:00  1178.0  764.8  508.4  1267.0  1211.0  30.7  73.7  3.0
# 2021-11-27 12:32:00  1178.0  763.6  509.4  1267.0  1211.0  30.9  72.4  2.7
# 2021-11-27 12:33:00  1180.0  771.7  504.5  1269.0  1213.0  30.9  72.9  2.5
# 2021-11-27 12:34:00  1184.0  778.5  502.0  1272.0  1215.0  31.1  72.7  2.2
# 2021-11-27 12:35:00  1194.0  779.0  511.3  1283.0  1226.0  31.4  70.7  2.6
# 2021-11-27 12:36:00  1210.0  775.9  530.1  1297.0  1240.0  31.5  69.2  2.8
# 2021-11-27 12:37:00  1202.0  770.6  526.6  1289.0  1232.0  31.4  68.6  2.8
# 2021-11-27 12:38:00  1187.0  755.0  525.6  1271.0  1214.0  31.3  68.7  2.9
#
#                      WSgust  WSstdev     WD  WDstdev      BP  Cleaning  \
# Timestamp
# 2021-10-30 11:12:00     1.9      0.6   69.5     12.6  1002.0       0.0
# 2021-10-30 13:03:00     2.6      0.5  205.7     11.9  1000.0       0.0
# 2021-10-30 13:11:00     2.1      0.4  220.2     12.5  1000.0       0.0
# 2021-11-06 12:13:00     3.9      0.5  301.7     17.7  1000.0       0.0
# 2021-11-06 12:14:00     4.1      0.7  296.8     15.4  1000.0       0.0
# 2021-11-06 12:15:00     4.4      0.9  256.2     20.6  1000.0       0.0
# 2021-11-11 12:18:00     1.9      0.5  327.0     21.8  1000.0       0.0
# 2021-11-11 12:19:00     2.1      0.7  290.6     10.8  1000.0       0.0
# 2021-11-11 12:20:00     2.9      0.4  300.8     13.9  1000.0       0.0
# 2021-11-27 12:27:00     3.1      0.4  299.6     20.2  1000.0       0.0
# 2021-11-27 12:28:00     3.6      0.5  279.4     10.1  1000.0       0.0
# 2021-11-27 12:29:00     2.6      0.5  306.0     17.8  1000.0       0.0
# 2021-11-27 12:30:00     3.1      0.7  264.5     27.0  1000.0       0.0
# 2021-11-27 12:31:00     3.6      0.5  282.3     22.1  1000.0       0.0
# 2021-11-27 12:32:00     3.9      0.5  294.2     19.3  1000.0       0.0
# 2021-11-27 12:33:00     3.6      0.7  311.0     16.7  1000.0       0.0
# 2021-11-27 12:34:00     3.1      0.6  263.5     24.2  1000.0       0.0
# 2021-11-27 12:35:00     3.4      0.7  245.4     29.9  1000.0       0.0
# 2021-11-27 12:36:00     3.6      0.6  217.2     16.9  1000.0       0.0
# 2021-11-27 12:37:00     3.6      0.4  201.4     11.0  1000.0       0.0
# 2021-11-27 12:38:00     3.4      0.4  210.3     14.7  1000.0       0.0
#
#                      Precipitation  TModA  TModB  Comments  GHI_zscore
# Timestamp
# 2021-10-30 11:12:00            0.0   66.1   59.2       NaN    3.013575
# 2021-10-30 13:03:00            0.0   69.5   66.0       NaN    3.003931
# 2021-10-30 13:11:00            0.0   62.4   61.0       NaN    3.110012
# 2021-11-06 12:13:00            0.0   59.8   58.2       NaN    3.023219
# 2021-11-06 12:14:00            0.0   60.2   58.7       NaN    3.048936
# 2021-11-06 12:15:00            0.0   60.7   59.1       NaN    3.026433
# 2021-11-11 12:18:00            0.0   58.7   56.5       NaN    3.264312
# 2021-11-11 12:19:00            0.0   60.8   58.4       NaN    3.180733
# 2021-11-11 12:20:00            0.0   62.5   59.9       NaN    3.151802
# 2021-11-27 12:27:00            0.0   55.6   55.7       NaN    3.052150
# 2021-11-27 12:28:00            0.0   56.8   56.8       NaN    3.077867
# 2021-11-27 12:29:00            0.0   57.7   57.9       NaN    3.100369
# 2021-11-27 12:30:00            0.0   59.3   59.4       NaN    3.097154
# 2021-11-27 12:31:00            0.0   60.8   60.7       NaN    3.090725
# 2021-11-27 12:32:00            0.0   61.5   61.5       NaN    3.090725
# 2021-11-27 12:33:00            0.0   62.0   62.0       NaN    3.097154
# 2021-11-27 12:34:00            0.0   63.2   62.9       NaN    3.110012
# 2021-11-27 12:35:00            0.0   64.2   64.0       NaN    3.142158
# 2021-11-27 12:36:00            0.0   65.0   64.6       NaN    3.193591
# 2021-11-27 12:37:00            0.0   66.1   65.2       NaN    3.167875
# 2021-11-27 12:38:00            0.0   67.0   65.6       NaN    3.119656

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='GHI', y='Tamb', size='RH', hue='WS', sizes=(20, 200), alpha=0.5)
plt.title('Bubble Chart of GHI vs. Temperature vs. Wind Speed')
plt.show()

# %%
df.fillna(df.mean(), inplace=True)

# %%
# Removing rows with extreme Z-scores
df = df[df['GHI_zscore'].abs() <= 3]

# %%
df.drop(columns=['Comments'], inplace=True)
